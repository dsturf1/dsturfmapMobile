# %%
import pandas as pd
import re
import os
import numpy as np
import glob
from datetime import datetime
import geopandas as gpd
import json
from shapely.geometry import shape, GeometryCollection
from rasterio.plot import show
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors
from utils import FeatureExtraction, feature_matching, decimal_coords
from exif import Image as exifimg
from PIL import Image

import shutil
import rasterio
import cv2
# %matplotlib inline

# %%
# 가능한 font list 확인
import matplotlib.font_manager as fm
f = [f.name for f in fm.fontManager.ttflist]
# print(f)

plt.rc('font', family='Malgun Gothic')

# %%
def getInfo(filesGrp, img_path):

  dslabel = {
    "id":"",
    "originalFileJPG":"",
    "originalFileGrp":[],
    "destFolder":"",
    "GeoTagInfo":{
      "coords":[],
      "datetime_original":"",
      "gps_altitude":0,
      "gps_altitude_ref":""    
    },
    "dest":{
      "rgb":"",
      "ndvi":"",
      "thumb":"",
    },
    "info":{
      "course":"",
      "area":"",
      "desc":"",
      "alt":""
    },
    "label":[],
    "annotation":[],
    "labelBy":""
  }

# Remove Drive letter with root path
  dslabel['originalFileJPG'] = img_path[3:]
  dslabel['originalFileGrp'] = [x[3:] for x in filesGrp  if ('.JPG' not in x)]

  with open(img_path, 'rb') as src:
    img = exifimg(src)

  coords = [
    decimal_coords(img.gps_longitude,
    img.gps_longitude_ref),
      decimal_coords(img.gps_latitude,
    img.gps_latitude_ref)
  ]

  dslabel['id'] = img.datetime_original.replace(" ","").replace(":","") + "_{:.10f}".format(coords[0]).replace(".","") + "_{:.10f}".format(coords[1]).replace(".","") + "_{:f}".format(img.gps_altitude).replace(".","")
  dslabel['GeoTagInfo']['coords'] = coords
  dslabel['GeoTagInfo']['datetime_original'] = img.datetime_original
  dslabel['GeoTagInfo']['gps_altitude'] = img.gps_altitude
  dslabel['GeoTagInfo']['gps_altitude_ref'] = img.gps_altitude_ref
  
  return dslabel

# %%
def getNDVIimg(filesGrp):


  with rasterio.open([ x for x in filesGrp if ('_MS_R' in x) ][0]) as src:
      band_red = src.read(1).astype(float)/65536.

  with rasterio.open([ x for x in filesGrp if ('_MS_NIR' in x) ][0]) as src:
      band_nir = src.read(1).astype(float)/65536.

  np.seterr(divide='ignore', invalid='ignore')

  # Calculate NDVI
  ndvi = (band_nir.astype(float) - band_red.astype(float)) / (band_nir.astype(float) + band_red.astype(float))

  ndvi -= ndvi.min() # ensure the minimal value is 0.0
  ndvi /= ndvi.max() # maximum value in image is now 1.0

  cm = plt.cm.get_cmap('RdYlGn')
  ndvi_cm = cm(ndvi)

  ndvi_img = cv2.normalize(ndvi_cm[:,:,:3], None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F).astype(np.uint8)

  return ndvi_img

# %%
def getalignedRGB(filesGrp_, ndvi_img):
  RGBimg = np.asarray(Image.open([x for x in filesGrp_ if 'JPG' in x][0]))

  # RGBimg = np.asarray(Image.open(filesGrp_[0]).resize((ndvi_img.shape[1],ndvi_img.shape[0])))
  # features0 = FeatureExtraction(RGBimg)
  # features1 = FeatureExtraction(ndvi_img)

  # matches = feature_matching(features0, features1)

  # print('{} number of matched has been found! in {}'.format(len(matches), filesGrp_[0]))

  # if len(matches) < 10:
  #    raise Exception("Not Enough Matches")

  # H, _ = cv2.findHomography( features0.matched_pts, features1.matched_pts, cv2.RANSAC, 5.0)

  H = np.array([[ 5.93209530e-01, -8.35074813e-03, -2.21474434e+02],
       [ 1.32198817e-02,  5.96460559e-01, -2.01042419e+02],
       [ 1.58520522e-06,  1.69424781e-06,  1.00000000e+00]])

  h, w, c = ndvi_img.shape
  RGBimg_tuned = cv2.warpPerspective(RGBimg, H, (w, h), borderMode=cv2.BORDER_CONSTANT, borderValue=(0, 0, 0, 0))

  return RGBimg_tuned

# %%
def single_file_process(file_, idx,   target_folder):

  path = os.path.normpath(file_)
  info = path.split(os.sep)

  area = info[root_index + 3]
  
  if len(info[root_index + 5].split('_')) ==3 :
    desc = info[root_index + 5].split('_')[-1] + '_0'
  else:
    desc = "미기재" + '_0'

  target_path = ('/').join([target_date,area,desc])

  while target_folder.count(target_path)>500:
    desc = desc.split('_')[0] + '_'+str(int(desc.split('_')[-1]) + 1)
    target_path = ('/').join([target_date,area,desc])

  target_folder.append(target_path)

  alt =  info[root_index + 4].split('_')[-1]


  filesGrp = glob.glob(os.path.join(os.path.split(file_)[0],(os.path.split(file_)[1].split('_')[0]+'_'+ 
    os.path.split(file_)[1].split('_')[1][:-3]+"***_" + os.path.split(file_)[1].split('_')[2]) + '*'), recursive=True)
  
  file_info = getInfo(filesGrp, file_)

  file_info['info']['course'] = course
  file_info['info']['area'] = area
  file_info['info']['alt'] = alt
  file_info['info']['desc'] = desc
  file_info['info']['date'] = target_date
  file_info['destFolder'] = target_path

  path_ = os.path.join(out_folder,course_id,target_date,area,desc,'rgb')

  if not os.path.exists(path_):
    os.makedirs(path_)

  path_ = os.path.join(out_folder,course_id,target_date,area,desc,'ndvi')

  if not os.path.exists(path_):
    os.makedirs(path_)

  path_ = os.path.join(out_folder,course_id,target_date,area,desc,'thumb')

  if not os.path.exists(path_):
    os.makedirs(path_)


  try:
    ndvi_img = getNDVIimg(filesGrp)
    rgb_img = getalignedRGB(filesGrp, ndvi_img)
    resized_ndvi = cv2.resize(ndvi_img, dsize=(648,486), interpolation=cv2.INTER_CUBIC)
    save_name = os.path.join(out_folder,course_id,target_date,area,desc,'ndvi','ndvi{}.JPG'.format( file_info['id']) )
    im = Image.fromarray(resized_ndvi)
    im.save(save_name)
    file_info['dest']['ndvi'] = save_name[9:]

    resized_rgb = cv2.resize(rgb_img , dsize=(2592,1944), interpolation=cv2.INTER_CUBIC)
    save_name = os.path.join(out_folder,course_id,target_date,area,desc,'rgb','rgb{}.JPG'.format( file_info['id']) )
    im = Image.fromarray(resized_rgb)
    im.save(save_name)
    file_info['dest']['rgb'] = save_name[9:]


    thumb_rgb = cv2.resize(rgb_img , dsize=(324,243), interpolation=cv2.INTER_CUBIC)
    save_name = os.path.join(out_folder,course_id,target_date,area,desc,'thumb','thumbrgb{}.JPG'.format( file_info['id']) )
    im = Image.fromarray(thumb_rgb)
    im.save(save_name)
    file_info['dest']['thumb'] = save_name[9:]

    InfoJsonArray.append( file_info)

  except Exception as e:
    print("{} file Error".format(idx) + str(e))
    logfile.write("{} file Error".format(idx) +'('+file_+')'+ str(e))
  
  print(save_name)
  print('{} out of {} files Completed'.format(idx, len(target_files)))

# %%
src_folder = r'D:\NIA_2023_52_잔디\01_원시데이터(분류)\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본'
out_folder = r'D:\ToAWS2'

course_list = ['청도','포항','중문','시흥','거창','속리산','춘천']

course_ids = {
  '포항':'MGC001',
  '청도':'MGC002',
  '중문':'MGC003',
  '시흥':'MGC004',
  '거창':'MGC005',
  '속리산':'MGC006',
  '춘천':'MGC007'
}

folder_type = ['rgb','ndvi','thumb']

# %%
logfile = open("err.log", "w")
original_folder = []

files = glob.glob(os.path.join(src_folder,'**/DJI_*.JPG'), recursive=True)

for file_ in files:
  path_ = os.path.normpath(file_)
  paths_ = path_.split(os.sep)
  path_ = (os.sep).join(paths_[0:root_index+4])

  if path_ not in original_folder:
    original_folder.append(path_)

print(original_folder)

course = list(filter(lambda y: y in src_folder, course_list))[0]
course_id = course_ids.get(course)

for img_folder in original_folder:

  print("Start processing the "  + img_folder)

  path_ = os.path.normpath(img_folder).split(os.sep)
  root_index = [idx for idx, s in enumerate(path_) if 'NIA_2023_52_잔디' in s][0]

  target_date = ('').join(path_[-1].split('_')[:2])
  area = path_[-1]

  InfoJsonArray = []
  target_folder = []

  for idx, file_ in enumerate(target_files):
    single_file_process(file_, idx, target_folder)

  save_name = os.path.join(out_folder,course_id,target_date,area, 'data'+target_date+area+'.json')
  with open(save_name, "w", encoding='utf-8') as final:
    json.dump(InfoJsonArray, final , ensure_ascii=False)
# Out:
# ['D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\10_스타트퍼팅그린', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\1_밸리6H', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\2_밸리7H', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\3_마운틴너스리포장', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\4_마운틴1H', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\5_마운틴2H', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\6_마운틴3H', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\7_레이크2H', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\8_레이크3H', 'D:\\NIA_2023_52_잔디\\01_원시데이터(분류)\\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\\9_레이크4H']
# Start processing the D:\NIA_2023_52_잔디\01_원시데이터(분류)\2023_0823_청도그레이스_맑고뭉게구름_데이터 1차 분류본\10_스타트퍼팅그린
# c:\anaconda3\envs\geo_James\lib\site-packages\rasterio\__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# C:\Users\yc463\AppData\Local\Temp\ipykernel_33196\891679340.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('RdYlGn')
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141700_1286408427222_356647967222_176816000.JPG
# 0 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141701_1286408431111_356647966944_176573000.JPG
# 1 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141703_1286408429722_356647968611_176528000.JPG
# 2 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141705_1286408424444_356647971111_176539000.JPG
# 3 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141707_1286408424722_356647974444_176569000.JPG
# 4 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141709_1286408407222_356647995000_176580000.JPG
# 5 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141711_1286408385556_356648013889_176550000.JPG
# 6 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141713_1286408356667_356648042222_176552000.JPG
# 7 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141715_1286408326389_356648071389_176593000.JPG
# 8 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141717_1286408326111_356648077222_176632000.JPG
# 9 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141719_1286408317778_356648092778_176617000.JPG
# 10 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141721_1286408309167_356648108333_176541000.JPG
# 11 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141723_1286408289167_356648130000_176555000.JPG
# 12 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141725_1286408261667_356648151667_176591000.JPG
# 13 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141727_1286408231667_356648185000_176526000.JPG
# 14 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141729_1286408216944_356648200000_176569000.JPG
# 15 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141731_1286408188333_356648223889_176611000.JPG
# 16 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141733_1286408156111_356648257778_176608000.JPG
# 17 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141735_1286408142778_356648270833_176564000.JPG
# 18 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141737_1286408120833_356648296111_176594000.JPG
# 19 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141739_1286408089167_356648325000_176565000.JPG
# 20 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141741_1286408059444_356648351111_176528000.JPG
# 21 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141743_1286408032222_356648373056_176570000.JPG
# 22 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141745_1286408003889_356648395833_176575000.JPG
# 23 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141747_1286407970278_356648428056_176502000.JPG
# 24 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141749_1286407980278_356648425000_176517000.JPG
# 25 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141751_1286407961944_356648446667_176628000.JPG
# 26 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141753_1286407913056_356648491111_176647000.JPG
# 27 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141755_1286407915000_356648495833_176653000.JPG
# 28 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141757_1286407934167_356648511389_176711000.JPG
# 29 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141759_1286407981111_356648536111_176798000.JPG
# 30 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141801_1286408003056_356648540278_176819000.JPG
# 31 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141803_1286408051111_356648579167_176796000.JPG
# 32 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141805_1286408080278_356648601111_176847000.JPG
# 33 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141807_1286408105000_356648609167_176879000.JPG
# 34 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141809_1286408132500_356648628333_176828000.JPG
# 35 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141811_1286408162500_356648609444_176802000.JPG
# 36 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141813_1286408200000_356648585000_176848000.JPG
# 37 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141815_1286408234444_356648556111_176866000.JPG
# 38 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141817_1286408279167_356648523056_176860000.JPG
# 39 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141819_1286408320278_356648488889_176780000.JPG
# 40 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141821_1286408363056_356648456111_176850000.JPG
# 41 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141823_1286408400278_356648429167_176817000.JPG
# 42 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141825_1286408417222_356648416111_176820000.JPG
# 43 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141827_1286408434444_356648400278_176804000.JPG
# 44 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141829_1286408458611_356648377500_176874000.JPG
# 45 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141831_1286408488056_356648355556_176715000.JPG
# 46 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141833_1286408524722_356648329167_176680000.JPG
# 47 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141835_1286408547500_356648313611_176766000.JPG
# 48 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141837_1286408565278_356648296667_176816000.JPG
# 49 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141839_1286408582500_356648286944_176741000.JPG
# 50 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141841_1286408598333_356648271111_176679000.JPG
# 51 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141843_1286408608056_356648266944_176718000.JPG
# 52 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141845_1286408610556_356648270000_176727000.JPG
# 53 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141847_1286408618333_356648263611_176747000.JPG
# 54 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141849_1286408614722_356648248333_176762000.JPG
# 55 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141851_1286408590000_356648226667_176729000.JPG
# 56 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141853_1286408546111_356648190833_176724000.JPG
# 57 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141855_1286408508333_356648166667_176718000.JPG
# 58 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141857_1286408481111_356648145000_176697000.JPG
# 59 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141859_1286408485278_356648106111_176721000.JPG
# 60 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141901_1286408509722_356648069167_176747000.JPG
# 61 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141903_1286408520556_356648049444_176701000.JPG
# 62 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141905_1286408518056_356648026389_176741000.JPG
# 63 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141907_1286408503889_356648008056_176761000.JPG
# 64 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141909_1286408484444_356647986389_176742000.JPG
# 65 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141911_1286408425278_356648016111_176706000.JPG
# 66 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141913_1286408371111_356648059444_176732000.JPG
# 67 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141915_1286408361389_356648068889_176704000.JPG
# 68 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141917_1286408350278_356648083611_176713000.JPG
# 69 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141919_1286408333333_356648104444_176682000.JPG
# 70 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141921_1286408329167_356648114722_176745000.JPG
# 71 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티_0\thumb\thumbrgb20230823141923_1286408329722_356648116944_176758000.JPG
# 72 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144106_1286408494167_356648049722_176438000.JPG
# 73 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144108_1286408500556_356648043056_176492000.JPG
# 74 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144110_1286408496389_356648025833_176432000.JPG
# 75 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144112_1286408493056_356648025278_176412000.JPG
# 76 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144114_1286408491667_356648023333_176486000.JPG
# 77 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144116_1286408490833_356648023333_176500000.JPG
# 78 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144118_1286408488889_356648016111_176468000.JPG
# 79 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144120_1286408487222_356648007778_176447000.JPG
# 80 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144122_1286408478333_356648001389_176417000.JPG
# 81 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144124_1286408458333_356647974722_176440000.JPG
# 82 out of 863 files Completed
# D:\ToAWS2\MGC002\10스타트퍼팅그린\5_마운틴2H\패취류,섬머패취,켄터키,티,물리적피해_0\thumb\thumbrgb20230823144126_1286408435000_356647951111_176462000.JPG
# 83 out of 863 files Completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\yc463\Documents\JamesLocal\DS\Drone\dsmapv2\src\AWS\(S1) DJI_File_Process copy.ipynb Cell 8 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=29'>30</a> target_folder = []
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=31'>32</a> for idx, file_ in enumerate(target_files):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=32'>33</a>   single_file_process(file_, idx, target_folder)
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=34'>35</a> save_name = os.path.join(out_folder,course_id,target_date,area, 'data'+target_date+area+'.json')
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=35'>36</a> with open(save_name, "w", encoding='utf-8') as final:
#
# c:\Users\yc463\Documents\JamesLocal\DS\Drone\dsmapv2\src\AWS\(S1) DJI_File_Process copy.ipynb Cell 8 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=48'>49</a>   os.makedirs(path_)
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=51'>52</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=52'>53</a>   ndvi_img = getNDVIimg(filesGrp)
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=53'>54</a>   rgb_img = getalignedRGB(filesGrp, ndvi_img)
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=54'>55</a>   resized_ndvi = cv2.resize(ndvi_img, dsize=(648,486), interpolation=cv2.INTER_CUBIC)
#
# c:\Users\yc463\Documents\JamesLocal\DS\Drone\dsmapv2\src\AWS\(S1) DJI_File_Process copy.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a> ndvi /= ndvi.max() # maximum value in image is now 1.0
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=17'>18</a> cm = plt.cm.get_cmap('RdYlGn')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=18'>19</a> ndvi_cm = cm(ndvi)
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a> ndvi_img = cv2.normalize(ndvi_cm[:,:,:3], None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F).astype(np.uint8)
#      <a href='vscode-notebook-cell:/c%3A/Users/yc463/Documents/JamesLocal/DS/Drone/dsmapv2/src/AWS/%28S1%29%20DJI_File_Process%20copy.ipynb#X16sZmlsZQ%3D%3D?line=22'>23</a> return ndvi_img
#
# File c:\anaconda3\envs\geo_James\lib\site-packages\matplotlib\colors.py:739, in Colormap.__call__(self, X, alpha, bytes)
#     736 if bytes:
#     737     lut = (lut * 255).astype(np.uint8)
# --> 739 rgba = lut.take(xa, axis=0, mode='clip')
#     741 if alpha is not None:
#     742     alpha = np.clip(alpha, 0, 1)
#
# KeyboardInterrupt:

# %% [markdown]
# Gather all data json files from Output Folder

# %%
dataJsonList = glob.glob(os.path.join(out_folder,course_id,target_date,'**/data*.json'), recursive=True)
dataJsonList
# Out:
# ['D:\\ToAWS\\MGC001\\20230816\\1.태백3H\\data202308161.태백3H.json',
#  'D:\\ToAWS\\MGC001\\20230816\\2.태백5H\\data202308162.태백5H.json',
#  'D:\\ToAWS\\MGC001\\20230816\\3.동해1H\\data202308163.동해1H.json',
#  'D:\\ToAWS\\MGC001\\20230816\\4.동해2H\\data202308164.동해2H.json',
#  'D:\\ToAWS\\MGC001\\20230816\\5.동해3H\\data202308165.동해3H.json',
#  'D:\\ToAWS\\MGC001\\20230816\\6.태백1H\\data202308166.태백1H.json']

# %%
folderinDataJson = []
totalPhotoJson = []

for dataJson_ in dataJsonList:
  with open(dataJson_, "r") as _json:
    dataJson= json.load(_json)
  
  totalPhotoJson.extend(dataJson)

  for Json_ in dataJson:
    if Json_['destFolder'] not in folderinDataJson:
      folderinDataJson.append(Json_['destFolder'])

# %%
save_name = os.path.join(out_folder,course_id,target_date, 'photo.json')
with open(save_name, "w", encoding='utf-8') as final:
   json.dump(totalPhotoJson, final , ensure_ascii=False)

# %%
filestructure = []


for folder_ in folderinDataJson:
  fileinfo = {}
  fileinfo["path"] = folder_
  fileinfo["file_cnt"] = len([ x for x in totalPhotoJson if x["destFolder"] == folder_])
  fileinfo["labeled_file_cnt"] = 0
  filestructure.append(fileinfo)

# %%
save_name = os.path.join(out_folder,course_id,target_date, 'filepath_'+course_id + '_'+target_date+'.json')
with open(save_name, "w", encoding='utf-8') as final:
   json.dump(filestructure, final , ensure_ascii=False)

# %%
len(totalPhotoJson)
# Out:
# 9184
